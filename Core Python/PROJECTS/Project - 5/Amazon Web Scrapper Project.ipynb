# %% [markdown]
# # Amazon Web Scrapper Project

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import datetime

import smtplib

# %%
# Connect to Website and pull in data

URL = 'https://www.amazon.in/U-S-Polo-Assn-Mens-Sneakers/dp/B0DQP8P1GD/ref=sr_1_50?crid=3IXQXD56QK8JF&dib=eyJ2IjoiMSJ9.lOQebpHUmxIqhGLDrXEBrGfdDUxJO1pJYYLFSsIx_aoaJ9tvtGVkkhNYdtM8esNXgNDw97tWMYJCMfwqd9K6eeKp8xmu1_XhGbfODhAVBpg6UyRq_-qm2uSO4l6sZ6h1-AsMckJpsdBBsrJoJmFTZui-3t72kmtGisGo4NH8ckBj8JpSeB0r2wwSqZYsKEo06QjsIx0fYzS5VYR6ZTX8aogkvLsOxBrE2FpGcgOoFi0IL-Fub-lCy1CWkqHYtWf72tng2FeeK8e23LUFQ_RckZ5iDNIqpHNtEexFo-RiHPY.wzDmO9BemN5oTMxM7cRgVfMNMWt39hdGRa40RA4ZGng&dib_tag=se&keywords=sneakers%2Bfor%2Bman&qid=1784053573&sprefix=sne%2Caps%2C319&sr=8-50&th=1&psc=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup1.find(id='productTitle').get_text()

price = soup1.find(class_ = 'a-price-whole').get_text()

print(title)
print(price)
# Out:
#         U.S. POLO ASSN. Mens Joan Sneakers
# 2,651.

# %%
# Cleanup Data
title = title.strip()
price = price.strip().replace(",", "").replace(".", "")

print(title)
print(price)
# Out:
# U.S. POLO ASSN. Mens Joan Sneakers
# 2651

# %%
# Create timestamp when data was collected

today = datetime.date.today()

print(today)
# Out:
# 2026-07-15

# %%
# Creating CSV and write headers and data into the file

import csv

header = ['Title', 'Price', 'Date']
data = [title, price, today]

with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df = pd.read_csv(r'D:\FBS\Core Python\PROJECTS\Project - 5\AmazonWebScraperDataset.csv')

print(df)
# Out:
#                                 Title  Price        Date
# 0  U.S. POLO ASSN. Mens Joan Sneakers   2651  2026-07-15

# %%
#Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %% [markdown]
# #### Combine all of the above code into one function

# %%
def check_price():
    URL = 'https://www.amazon.in/U-S-Polo-Assn-Mens-Sneakers/dp/B0DQP8P1GD/ref=sr_1_50?crid=3IXQXD56QK8JF&dib=eyJ2IjoiMSJ9.lOQebpHUmxIqhGLDrXEBrGfdDUxJO1pJYYLFSsIx_aoaJ9tvtGVkkhNYdtM8esNXgNDw97tWMYJCMfwqd9K6eeKp8xmu1_XhGbfODhAVBpg6UyRq_-qm2uSO4l6sZ6h1-AsMckJpsdBBsrJoJmFTZui-3t72kmtGisGo4NH8ckBj8JpSeB0r2wwSqZYsKEo06QjsIx0fYzS5VYR6ZTX8aogkvLsOxBrE2FpGcgOoFi0IL-Fub-lCy1CWkqHYtWf72tng2FeeK8e23LUFQ_RckZ5iDNIqpHNtEexFo-RiHPY.wzDmO9BemN5oTMxM7cRgVfMNMWt39hdGRa40RA4ZGng&dib_tag=se&keywords=sneakers%2Bfor%2Bman&qid=1784053573&sprefix=sne%2Caps%2C319&sr=8-50&th=1&psc=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup1.find(id='productTitle').get_text()

    price = soup1.find(class_ ='a-price-whole').get_text()

    title = title.strip()
    price = price.strip().replace(",", "").replace(".", "")

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# check_price after a set time and inputs data into your CSV

# while(True):
#     check_price()
#     # time.sleep(60)

# %%
df = pd.read_csv(r'D:\FBS\Core Python\PROJECTS\Project - 5\AmazonWebScraperDataset.csv')

print(df)
# Out:
#                                 Title  Price        Date
# 0  U.S. POLO ASSN. Mens Joan Sneakers   2651  2026-07-15
# 1  U.S. POLO ASSN. Mens Joan Sneakers   2651  2026-07-15
# 2  U.S. POLO ASSN. Mens Joan Sneakers   2651  2026-07-15
