# %% [markdown]
# # Automatic File Sorter in File Explorer

# %%
import os, shutil

# %%
path = r'D:/FBS/Core Python/PROJECTS/Project - 3/Demo/'

# %%
file_name =  os.listdir(path)
print(file_name)
# Out:
# ['CSV Files', 'image 1.jpg', 'image 2.jpg', 'Image Files', 'Text Files', 'txt.txt', 'Word Files']

# %%
folder_names = ['CSV Files', 'Text Files', 'Image Files', 'Word Files']

for i in range(0,4):
    if not os.path.exists(path + folder_names[i]):
        print(path + folder_names[i])
        os.makedirs(path + folder_names[i])

for file in file_name:
    if ".csv" in file and not os.path.exists(path + "CSV Files/" + file):
        shutil.move(path + file, path + "CSV Files/" + file)
    elif ".txt" in file and not os.path.exists(path + "Text Files/" + file):
        shutil.move(path + file, path + "Text Files/" + file)
    elif ".jpg" in file and not os.path.exists(path + "Image Files/" + file):
        shutil.move(path + file, path + "Image Files/" + file)
    elif ".docx" in file and not os.path.exists(path + "Word Files/" + file):
        shutil.move(path + file, path + "Word Files/" + file)
    # else:
    #     print("There are files")
